# %%
import os
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pheno = pd.read_csv('/Users/macbookair/Downloads/Data/Phenotypic/allSubs_testSet_phenotypic_dx.csv', index_col='ID')

# %%
df_pheno
# Out:
#         Disclaimer  Site  Gender    Age  Handedness DX Secondary Dx   \
# ID
# 1038415        NaN     1       1  14.92         1.0  3           ODD
# 1201251        NaN     1       1  12.33         1.0  3           NaN
# 1245758        NaN     1       0   8.58         1.0  0           NaN
# 1253411        NaN     1       1   8.08         1.0  0           NaN
# 1419103        NaN     1       0   9.92         1.0  0           NaN
# ...            ...   ...     ...    ...         ... ..           ...
# 25008          NaN     7       1  15.90         1.0  3           NaN
# 25009          NaN     7       1  13.87         1.0  0           NaN
# 25012          NaN     7       0  15.04         1.0  3           NaN
# 25013          NaN     7       1  13.64         1.0  0           NaN
# 25014          NaN     7       1  13.72         1.0  3           NaN
#
#         ADHD Measure ADHD Index Inattentive  ... Verbal IQ Performance IQ  \
# ID                                           ...
# ...

# %%
plt.figure(figsize=(16,10))

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_pheno.corr(), annot=True)
# Out:
# /var/folders/br/h0l3g63n0fd2drw0qg88mqk40000gn/T/ipykernel_2585/1760270630.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_pheno.corr(), annot=True)
# <Axes: >

# %%
df_pheno.corr()
# Out:
# /var/folders/br/h0l3g63n0fd2drw0qg88mqk40000gn/T/ipykernel_2585/4122710696.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_pheno.corr()
#                      Site    Gender       Age  Handedness  IQ Measure  \
# Site             1.000000  0.029139 -0.011733   -0.175285   -0.316265
# Gender           0.029139  1.000000 -0.070633   -0.132351   -0.144558
# Age             -0.011733 -0.070633  1.000000    0.083538    0.672274
# Handedness      -0.175285 -0.132351  0.083538    1.000000    0.125732
# IQ Measure      -0.316265 -0.144558  0.672274    0.125732    1.000000
# Verbal IQ       -0.277650  0.012302 -0.117646    0.079527    0.224861
# Performance IQ  -0.055516  0.040415 -0.104340    0.010495   -0.156839
# Full2 IQ         0.999859 -0.124051  0.855541   -0.226135    0.999859
# ...

# %%
df_pheno['DX'].value_counts()
# Out:
# 0          94
# 1          49
# 3          26
# pending    26
# 2           2
# Name: DX, dtype: int64
